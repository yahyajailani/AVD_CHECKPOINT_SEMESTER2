# %% [markdown]
# # **Analisis Pola dan Tren Perilaku Belanja Konsumen Berdasarkan Data Transaksi**

# %% [markdown]
# Nama: Yahya Jailani
#
# Kelas: C
#
# NIM: 2509116085

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd

# %% [markdown]
# # **Memuat Dataset**

# %%
file = '/content/shopping_behavior_updated (1).csv'
df = pd.read_csv(file)

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df.head(10)
# Out:
#    Customer ID  Age Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse     Clothing                     53
# 1            2   19   Male        Sweater     Clothing                     64
# 2            3   50   Male          Jeans     Clothing                     73
# 3            4   21   Male        Sandals     Footwear                     90
# 4            5   45   Male         Blouse     Clothing                     49
# 5            6   46   Male       Sneakers     Footwear                     20
# 6            7   63   Male          Shirt     Clothing                     85
# 7            8   27   Male         Shorts     Clothing                     34
# 8            9   26   Male           Coat    Outerwear                     97
# 9           10   57   Male        Handbag  Accessories                     31
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# ...

# %%
df.tail(10)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3890         3891   35  Female          Shirt     Clothing
# 3891         3892   36  Female          Dress     Clothing
# 3892         3893   35  Female        Jewelry  Accessories
# 3893         3894   21  Female            Hat  Accessories
# 3894         3895   66  Female          Skirt     Clothing
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 3890                     81       Nebraska   XL      Green  Winter
# 3891                     30       Colorado    L      Peach  Winter
# 3892                     86       Michigan    L     Indigo  Summer
# ...

# %% [markdown]
# # **Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/MyDrive/Praktikum Season 2/shopping_behavior_updated (1).csv'
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(path)
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# Perusahaan perlu memahami pola perilaku belanja konsumen dari data transaksi yang tersedia untuk mengoptimalkan strategi pemasaran dan meningkatkan nilai transaksi. Analisis ini bertujuan mengidentifikasi minimal tiga pola signifikan dan menghasilkan rekomendasi strategis yang dapat meningkatkan rata-rata nilai transaksi sebesar 8 sampai dengan 10% dalam enam bulan. Fokus analisis mencakup pengaruh kependudukan terhadap pola pembelian, tren musiman dan geografis, serta faktor-faktor utama yang mendorong nilai transaksi dan kepuasan pelanggan.

# %% [markdown]
# ## **1. Business Objective**

# %% [markdown]
# 1. Tujuan Bisnis: Memahami pola dan tren perilaku belanja konsumen untuk mengoptimalkan strategi pemasaran dan meningkatkan nilai transaksi.
# 2. Kriteria Kesuksesan:
#
# *  Teridentifikasinya 3 pola/tren perilaku belanja signifikan dari data transaksi.
#
# *  Dihasilkannya rekomendasi strategis yang dapat ditindaklanjuti.
#
# *  Meningkatnya rata-rata nilai transaksi sebesar 8 hingga 10% dalam 6 bulan pasca implementasi.
#
# Pertanyaan Bisnis yang digunakan:
#
# 1. Bagaimana pola pembelian bervariasi berdasarkan usia dan jenis kelamin?
#
# 2. Bagaimana tren pembelian berubah berdasarkan musim?
#
# 3. Apakah ada pola musiman untuk kategori produk tertentu?
#
# 4. Apa korelasi antara diskon, status langganan, dan metode pembayaran dengan nilai transaksi serta kepuasan pelanggan?

# %% [markdown]
# ## **2. Asses Situation**

# %% [markdown]
# Inventarisasi Sumber Daya:
#
# * Data: Dataset dengan 3.900 entri pelanggan, mencakup variabel: 'Customer ID, Age, Gender, Item Purchased, Category, Purchase Amount (USD), Location, Size, Color, Season, Review Rating, Subscription Status, Discount Applied, Previous Purchases, Payment Method, Frequency of Purchases'.
#
# * Alat Analitik: Tools untuk analisis data seperti Python (Pandas, Scikit-learn), R, atau platform analisis visual seperti Tableau.
#
# * Keahlian: Tim data scientist atau analis data yang mampu melakukan analisis eksplorasi data, segmentasi pelanggan, analisis korelasi dan pemodelan.
#
# * Pemangku Kepentingan: Manajer produk, tim pemasaran, tim pengembangan algoritma rekomendasi, dan tim strategi bisnis.
#
# Kerangka konseptual ini dapat digunakan untuk mengidentifikasi pola perilaku konsumen serta merumuskan strategi pemasaran yang tepat hingga pada akhirnya meningkatkan retensi dan nilai transaksi pelanggan secara berkelanjutan.

# %% [markdown]
# ## **3. Analytic Goals & Project Plan**

# %% [markdown]
# Berdasarkan tujuan bisnis, tujuan analitik dirumuskan sebagai berikut:
#
# 1. Peluang Perusahaan: Membuka peluang untuk perusahaan dalam memasarkan produk dengan waktu yang tepat mengikuti perkembangan tren dan alur sosial media seperti Tiktok, Instagram, DLL.
#
# 2. Prediksi: Mengembangkan model untuk memprediksi kelompok usia atau preferensi perangkat berdasarkan pola penggunaan.
#
# 3. Rekomendasi Strategi: Memberikan rekomendasi spesifik untuk penargetan algoritma dan personalisasi konten untuk setiap kalangan.
#
# Analisis ini juga relevan bagi pemerintah atau pengelola platform media sosial. Wawasan yang sama dapat digunakan untuk kampanye sosial positif, namun berpotensi disalahgunakan untuk membentuk opini publik atau mengeksploitasi kelompok tertentu.
#
# Projek Plan untuk bisnis:
#
# ### Fase 1: Persiapan dan Pemahaman Data
# * Mengumpulkan dan memvalidasi data dari file shopping_behavior_updated (1).csv.
# * Melakukan eksplorasi data awal (EDA) untuk memahami distribusi, missing values, dan outliers.
# * Mendefinisikan metrik evaluasi yang sejalan dengan kriteria kesuksesan bisnis.
#
# ### Fase 2: Analisis Eksploratori dan Segmentasi
# * Analisis statistik deskriptif untuk setiap kelompok usia. Visualisasi pola penggunaan (misalnya, rata-rata jumlah pembelian per kategori produk per kelompok usia).
# * Melakukan analisis klaster (clustering) untuk mengidentifikasi segmen pengguna yang homogen di dalam atau antar kelompok usia.
#
# ### Fase 3: Pemodelan dan Analisis Lanjutan
# * Mengembangkan model klasifikasi untuk memprediksi kelompok usia berdasarkan variabel penggunaan.
# * Uji statistik untuk memvalidasi perbedaan signifikan antar kelompok.
